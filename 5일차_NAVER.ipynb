# %% [markdown]
# # 네이버에서 헤드라인 뉴스 목록 가져오기

# %%
# HTML 관련 모듈 호출
from bs4 import BeautifulSoup
import urllib.request as req

# 접속할 사이트 주소 입력
url = 'https://news.naver.com/'

# 지정된 사이트 접속
res = req.urlopen(url)

# 접속된 사이트의 HTML 태그 분석
soup = BeautifulSoup(res, 'html.parser')

# 태그출력
# soup

# 원하는 부분 출력하기 (여기서는 헤드라인 뉴스 목록)
results = soup.select('div.hdline_article_tit > a')

for result in results:
    print(result.string.strip())
# Out:
# 운동부 후배의 ‘끓는물 학대’ 못 벗어난 건 협박과 차용증 때문(종합)
# 여권의 '집값이몽'…추미애·이재명 부동산정책 자기 목소리
# 의원 300명에게 편지 보낸 이재명… '차기대선 겨냥' 몸풀기?
# 진성준, 국토위 변경 요구에 "안 물러나"…게시판엔 징계주장
# 확진자 사흘 만에 30명대…39명 중 28명 해외발

# %% [markdown]
# # 뉴스토픽 가져오기

# %%
# HTML 관련 모듈 호출
from bs4 import BeautifulSoup
import urllib.request as req

# 접속할 사이트 주소 입력
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=105'

# 지정된 사이트 접속
res = req.urlopen(url)

# 접속된 사이트의 HTML 태그 분석
soup = BeautifulSoup(res, 'html.parser')

# 태그출력
# soup

# 원하는 부분 출력하기 (여기서는 뉴스토픽 목록)
results = soup.select('strong.title')

for result in results:
    print(result.string.strip())
# Out:
# 오늘의 날씨
# 전 채널A 기자
# WSJ 미 국방부
# 박원순 의혹에
# 코로나19 이후
# 뉴욕증시 0.23% 하락 마감
# 코로나 백신
# 수돗물 유충
# 주한미군 감축 가능성에
# 코로나19 확산
# 여름방학 정유미
# 편의점 샛별이 지창욱
# 우아한 친구들 송윤아
# 나혼산 화사
# 김유정 직진 사랑 펼칠까
# PPL 논란 강민경
# 알고보니 KBS 아들
# 오늘 공개
# 나혼산 장도연
# 놀면 뭐하니 싹쓰리

# %% [markdown]
# # 분야별 주요뉴스 가져오기

# %%
#%%writefile d:/weekend/news.py

# HTML 관련 모듈 호출
from bs4 import BeautifulSoup
import urllib.request as req

# 접속할 사이트 주소 입력
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=105'

# 지정된 사이트 접속
res = req.urlopen(url)

# 접속된 사이트의 HTML 태그 분석
soup = BeautifulSoup(res, 'html.parser')

# 태그출력
# soup

# 원하는 부분 출력하기 (여기서는 분야별 주요뉴스 목록)
results = soup.select('ul.list_txt > li > a')

for result in results:
    print(result.string.strip())
# Out:
# 진성준, 국토위 변경 요구에 "안 물러나"…게시판엔 징계주장
# 문 대통령 "개인투자자 응원해야"…주식양도세 사실상 제동
# 날개 단 이재명 "수술실 CCTV 의무화" 국회에 호소 편지
# 주한미군 감축설에 '발칵'…美정치권도 "北에 잘못된 신호"
# 中 코로나 하루 확진자 22명… 신장에서만 16명 발생
# ‘그린뉴딜’ 한다며 그린벨트 해제?… 주택 공급 대책에 거센 반발
# 셀트리온 코로나19 항체 치료제 임상 1상 승인…국내 신약 최초
# [단독] 정몽구 현대차그룹 회장 입원
# "삼성전자, 4분기 '갤럭시S 20 팬 에디션' 출시 전망"
# 반려견 암 치료 위한 유전자 지도 만들었다
# 전 채널A 기자 구속, 측근 감싸기로 입지 좁아진 윤석열
# 코로나19 신규 확진 39명…해외유입 28명·국내발생 11명
# 이만희 총회장 첫 소환조사, 지병호소로 4시간만에 종료
# [날씨] 한낮 무더위…전남·제주 장맛비 시작
# ‘사적 대화 무단 인용 논란’ 김봉곤 소설집 판매중지

# %% [markdown]
# # 가장 많이 본 뉴스 목록 가져오기

# %%
# HTML 관련 모듈 호출
from bs4 import BeautifulSoup
import urllib.request as req

# 접속할 사이트 주소 입력
url = 'https://news.naver.com/'

# 지정된 사이트 접속
res = req.urlopen(url)

# 접속된 사이트의 HTML 태그 분석
soup = BeautifulSoup(res, 'html.parser')

# 태그출력
# soup

# 원하는 부분 출력하기 (여기서는 가장 많이 본 뉴스 목록)
results = soup.select('ul.section_list_ranking > li > a')

for result in results:
    print(result.string.strip())
# Out:
# "그린벨트 풀면 서울 투기판 된다" 집값문제 끼어든 추미애
# 의원 300명에게 편지 보낸 이재명… '차기대선 겨냥' 몸풀기?
# 더 시끄러운 여당…이재명 "비싼 집 사는게 죄?", 진성준 "집값 안떨어져"
# 안희정·오거돈 때와 다른 민주당…왜 이토록 박원순 감쌀까 [정치TMI]
# 코로나 확진자 없다는 北 이번엔 "백신개발 막바지"
# 추미애, 차량의전 의혹에 "자다가 봉창"…조수진 "이런게 꼰대"
# “3040 문재인에 속았다…국토위 사퇴” 진성준 유감에 ‘공분’
# 이재명 "수술실 CCTV 의무화해달라" 국회의원 전원에게 편지
# 진중권 "영장판사가 '검언신뢰 회복' 언급…명백히 정치적"
# 여권 차기 대권주자 지각 변동, 2강으로 가나
# 2030 겨눈 마트 6080이 신문지 깔았다…신촌서 생긴 일
# “남은 사다리 걷어차” 역풍 불자… 文대통령 정책 수정 지시
# 靑도 가세 강남 ‘그린벨트’ 풀린다···사자 문의에 호가뛴 '세곡·내곡’
# "재산세 너무 올랐다" 거리로 나서는 조세저항
# 재산세 고지서 받고 '헉'…부동산 커뮤니티 ‘부글부글'
# 고교생 "65만원짜리 신발 갖고싶어요"…10대 절반이 명품 사봤다
# 추미애 "그린벨트 해제 안돼"…법무장관의 '부동산 정책 제안'
# 미르재단 닮은꼴 새 로고?…인천공항 "다른 것 찾겠다"
# 내집마련 꿈 걷어차인 3040의 '이유 있는 분노'
# 셀트리온 코로나19 항체 치료제 임상 1상 승인…국내 신약 최초
# 임순영 "건강 이유로 경찰 조사 못 받아, 일정 협의중"
# 文 대통령에 신발 던진 50대 남성 구속영장…"사안 매우 중해"
# '여가부 해체론' 나오자…장관 뒤늦게 "깊은 책임 통감"
# 운동부 후배의 ‘끓는물 학대’ 못 벗어난 건 협박과 차용증 때문(종합)
# "말도 못 해요. 징그러워서"...대벌레 은평 봉산 무더기 출몰
# 신혼여행 다녀오니 날벼락…“번호판 가려졌다” 과태료 50만원 통지 [김기자와 만납시다]
# "성인 뛰어넘는 지능범" 숙명여고 쌍둥이에 실형 구형
# ...

# %% [markdown]
# # IT/과학 뉴스 타이틀 가져오기

# %%
# HTML 관련 모듈 호출
from bs4 import BeautifulSoup
import urllib.request as req

# 접속할 사이트 주소 입력
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=105'

# 지정된 사이트 접속
res = req.urlopen(url)

# 접속된 사이트의 HTML 태그 분석
soup = BeautifulSoup(res, 'html.parser')

# 태그출력
# soup

# 원하는 부분 출력하기 
results = soup.select('div.cluster_text a')

for result in results:
    print(result.string.strip())
# Out:
# "삼성전자, 4분기 '갤럭시S 20 팬 에디션' 출시 전망"
# 삼성 신형 스마트밴드, 갤노트20와 등장할까...8월 언팩 공개 가능성 솔솔
# “이것이 갤럭시노트20” 새 렌더링 등장.. 플랫 화면 눈길
# [장기자의 비사이드IT]'갤럭시폴드2'는 과연 '언팩'에 출연할까
# 반려견 암 치료 위한 유전자 지도 만들었다
# "개도 사람처럼" 반려견 암질환…유전자 정밀의료 토대 마련됐다
# 주말 저녁 북서쪽 하늘보니…23년만에 ‘혜성쇼’
# "이번주가 관측 최적"···천문연 '니오와이즈 혜성' 촬영 사진 공개
# 얻어맞고도 끄떡없는 화웨이… 美 "이래도 버틸래?"
# TSMC도 화웨이와 '거래중단'..."화웨이 어쩌나"
# 서울 센터·엣지 키우는 AWS…클라우드 인프라 경쟁 더 뜨거워졌다
# 격해지는 클라우드 경쟁··· 아마존 데이터센터 확장, “선두는 나”
# [표지로 읽는 과학] 망간에서 생존 에너지 얻는 미생물
# [표지로 읽는 과학]박쥐는 머릿 속 이미지로 길을 찾는다
# [표지로 읽는 과학]여러달 걸릴 실험 며칠 만에 끝내는 '로봇 화학자'의 탄생
# [표지로 읽는 과학] 고대 미생물 품은 오아시스 '기사회생'
# [사이언스샷] 인류 역사상 가장 가까이서 본 태양의 모습
# [IF] [사이언스샷] 호주 바다에 살던 '인어'가 사라졌다
# [사이언스샷] 호주의 팔 달린 인어, 바다어류로 첫 멸종
# [사이언스샷] 이식 못할 죽은 폐, 돼지가 되살린다

# %% [markdown]
# # 타이틀 & 링크주소 가져오기

# %%
# HTML 관련 모듈 호출
from bs4 import BeautifulSoup
import urllib.request as req

# 접속할 사이트 주소 입력
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=105'

# 지정된 사이트 접속
res = req.urlopen(url)

# 접속된 사이트의 HTML 태그 분석
soup = BeautifulSoup(res, 'html.parser')

# 태그출력
# soup

# 원하는 부분 출력하기 
results = soup.select('div.cluster_text a')

for result in results:
    print("제목 : ", result.string)
    print("링크주소 : ", result.attrs['href'])
    print()
# Out:
# 제목 :  "삼성전자, 4분기 '갤럭시S 20 팬 에디션' 출시 전망"
# 링크주소 :  https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=003&aid=0009974703
#
# 제목 :  삼성 신형 스마트밴드, 갤노트20와 등장할까...8월 언팩 공개 가능성 솔솔
# 링크주소 :  https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=011&aid=0003770378
#
# 제목 :  “이것이 갤럭시노트20” 새 렌더링 등장.. 플랫 화면 눈길
# 링크주소 :  https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=014&aid=0004463163
#
# 제목 :  [장기자의 비사이드IT]'갤럭시폴드2'는 과연 '언팩'에 출연할까
# 링크주소 :  https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=018&aid=0004692837
#
# 제목 :  반려견 암 치료 위한 유전자 지도 만들었다
# 링크주소 :  https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=023&aid=0003547302
#
# 제목 :  "개도 사람처럼" 반려견 암질환…유전자 정밀의료 토대 마련됐다
# 링크주소 :  https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=421&aid=0004762285
#
# 제목 :  주말 저녁 북서쪽 하늘보니…23년만에 ‘혜성쇼’
# 링크주소 :  https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=008&aid=0004441814
#
# ...

# %% [markdown]
# # 네이버 뉴스 본문 가져오기

# %%
# HTML 관련 모듈 호출
from bs4 import BeautifulSoup
import urllib.request as req

# 접속할 사이트 주소 입력
url = 'https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=215&aid=0000886822'

# 지정된 사이트 접속
res = req.urlopen(url)

# 접속된 사이트의 HTML 태그 분석
soup = BeautifulSoup(res, 'html.parser')

# 태그출력
# soup

# 원하는 부분 출력하기 
results = soup.select_one('#articleBodyContents')

output = ""

for result in results.contents:
    output += str(result)
    
print(output)
# Out:
#  본문 내용
#  TV플레이어
#  // TV플레이어
# <script type="text/javascript">
# // flash 오류를 우회하기 위한 함수 추가
# function _flash_removeCallback() {}
# </script>
# ...

# %% [markdown]
# # 분야별 뉴스 목록 가져오기

# %%
# 방법 1
from bs4 import BeautifulSoup
import urllib.request as req

url = "https://news.naver.com"
res = req.urlopen(url)
soup = BeautifulSoup(res, 'html.parser')

print('-'*80)
print('헤드라인')

results = soup.select('div.hdline_article_tit > a')

for result in results:
    name = result.string
    print("♨", name.strip())

# 위의 코드를 '헤드라인' 부분만 정치, 경제 등으로 바꾸어서 반복 작성
# Out:
# --------------------------------------------------------------------------------
# 헤드라인
# ♨ 검찰·언론 때리던 추미애, 법무부와 관계 없는 "그린벨트 해제 반대"…왜?
# ♨ "노무현 대통령은 어떻게 했을까…" 봉하 찾은 김부겸
# ♨ '박원순 고소 유출' 규명 기대 젠더특보 소환 더뎌…공은 검찰로
# ♨ 월스트리트저널 "미 국방부, 주한미군 감축안 백악관에 제시"
# ♨ 의왕 플라스틱 용기 공장 큰불로 11명 다쳐..."큰 폭발음 들렸다"

# %%
# 방법 2
from bs4 import BeautifulSoup
import urllib.request as req

url = "https://news.naver.com"
res = req.urlopen(url)
soup = BeautifulSoup(res, 'html.parser')

naver_news = {
    '헤드라인 뉴스' : 'div.hdline_article_tit > a',
    '정치' : '#section_politics > div > div > ul > li > a > strong',
    '경제' : '#section_economy > div > div > ul > li > a > strong',
    '사회' : '#section_society > div > div > ul > li > a > strong',
    '생활/문화' : '#section_life > div > div > ul > li > a > strong',
    '세계' : '#section_world > div > div > ul > li > a > strong',
    'IT/과학' : '#section_it > div > div > ul > li > a > strong'}

for key, value in naver_news.items():
    print('-'*80)
    print(key)
    news_list = soup.select(value)
    for li in news_list:
        name = li.string
        print('♨', name.strip())
# Out:
# --------------------------------------------------------------------------------
# 헤드라인 뉴스
# ♨ 검찰·언론 때리던 추미애, 법무부와 관계 없는 "그린벨트 해제 반대"…왜?
# ♨ "노무현 대통령은 어떻게 했을까…" 봉하 찾은 김부겸
# ♨ 의왕 플라스틱 용기 공장 큰불로 11명 다쳐..."큰 폭발음 들렸다"
# ♨ 경찰 수사 주말에도 계속…임순영 젠더특보 소환 초읽기
# ♨ 이동재 전 채널A 기자 구속 증거 인멸 우려
# --------------------------------------------------------------------------------
# 정치
# ♨ 노회찬 찾은 심상정 "거센 논란 통해 더 성숙해지고 단단해지겠다"
# ♨ '추미애 저격수' 된 통합당 초선 조수진 "이런게 꼰대"
# ♨ "노무현 대통령은 어떻게 했을까…" 봉하 찾은 김부겸
# ♨ 현실화된 文정부 '조세저항'…통합당, 부동산 연일 때리기
# ♨ 심상정, 故노회찬 추모하며 "면목 없지만 더 당당해지겠다"
# --------------------------------------------------------------------------------
# 경제
# ♨ 추미애 “그린벨트 풀면 서울 투기판”…정책 실패는 이전 정부 탓
# ♨ 카카오게임즈, 장외시장서 ‘각광’…시총 3조원 육박 ‘눈길’
# ♨ [단독] ‘알짜’ 친척계열사 9년간 숨겨온 하이트진로…공정위 조사 착수
# ♨ [시승기] 르노삼성차, SM6 '심장병' 고쳤다…두근거리는 트랙 주행
# ♨ [김유성의 금융CAST]약발 다된 기준금리 인하?
# --------------------------------------------------------------------------------
# 사회
# ♨ “엄마, 나도 분필 먹고 싶어요” 선넘는 먹방들[김채현의 EN톡]
# ...

# %% [markdown]
# 딕셔너리함수()
#
# 1. items() : 키와 값을 출력
# 2. keys() : 키만 출력
# 3. values() : 값만 출력

# %% [markdown]
# # 네이버뉴스를 엑셀로 저장하기

# %%
# -*- coding: utf-8 -*-
from bs4 import BeautifulSoup
from datetime import datetime
import requests
import pandas as pd
import re
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''
< naver 뉴스 검색시 리스트 크롤링하는 프로그램 > _select사용
- 크롤링 해오는 것 : 링크,제목,신문사,날짜,내용요약본
- 날짜,내용요약본  -> 정제 작업 필요
- 리스트 -> 딕셔너리 -> df -> 엑셀로 저장 
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''

#각 크롤링 결과 저장하기 위한 리스트 선언 
title_text=[]
link_text=[]
source_text=[]
date_text=[]
contents_text=[]
result={}

#엑셀로 저장하기 위한 변수
RESULT_PATH ='d:/'  #결과 저장할 경로
now = datetime.now() #파일이름 현 시간으로 저장하기

#날짜 정제화 함수
def date_cleansing(test):
    try:
        #지난 뉴스
        #머니투데이  10면1단  2020.07.05.  네이버뉴스   보내기  
        pattern = '\d+.(\d+).(\d+).'  #정규표현식 
    
        r = re.compile(pattern)
        match = r.search(test).group(0)  # 2020.07.05.
        date_text.append(match)
        
    except AttributeError:
        #최근 뉴스
        #이데일리  1시간 전  네이버뉴스   보내기  
        pattern = '\w* (\d\w*)'     #정규표현식 
        
        r = re.compile(pattern)
        match = r.search(test).group(1)
        #print(match)
        date_text.append(match)


#내용 정제화 함수 
def contents_cleansing(contents):
    first_cleansing_contents = re.sub('<dl>.*?</a> </div> </dd> <dd>', '', 
                                      str(contents)).strip()  #앞에 필요없는 부분 제거
    second_cleansing_contents = re.sub('<ul class="relation_lst">.*?</dd>', '', 
                                       first_cleansing_contents).strip()#뒤에 필요없는 부분 제거 (새끼 기사)
    third_cleansing_contents = re.sub('<.+?>', '', second_cleansing_contents).strip()
    contents_text.append(third_cleansing_contents)
    #print(contents_text)
    

def crawler(maxpage,query,sort,s_date,e_date):

    s_from = s_date.replace(".","")
    e_to = e_date.replace(".","")
    page = 1  
    maxpage_t =(int(maxpage)-1)*10+1   # 11= 2페이지 21=3페이지 31=4페이지  ...81=9페이지 , 91=10페이지, 101=11페이지
    
    while page <= maxpage_t:
        url = "https://search.naver.com/search.naver?where=news&query=" + query + "&sort="+sort+"&ds=" + s_date + "&de=" + e_date + "&nso=so%3Ar%2Cp%3Afrom" + s_from + "to" + e_to + "%2Ca%3A&start=" + str(page)
        
        response = requests.get(url)
        html = response.text
 
        #뷰티풀소프의 인자값 지정
        soup = BeautifulSoup(html, 'html.parser')
 
        #<a>태그에서 제목과 링크주소 추출
        atags = soup.select('._sp_each_title')
        for atag in atags:
            title_text.append(atag.text)     #제목
            link_text.append(atag['href'])   #링크주소
            
        #신문사 추출
        source_lists = soup.select('._sp_each_source')
        for source_list in source_lists:
            source_text.append(source_list.text)    #신문사
        
        #날짜 추출 
        date_lists = soup.select('.txt_inline')
        for date_list in date_lists:
            test=date_list.text   
            date_cleansing(test)  #날짜 정제 함수사용 
        
        #본문요약본
        contents_lists = soup.select('ul.type01 dl')
        for contents_list in contents_lists:
            #print('==='*40)
            #print(contents_list)
            contents_cleansing(contents_list) #본문요약 정제화
        
        
        #모든 리스트 딕셔너리형태로 저장
        result= {"date" : date_text , "title":title_text ,  "source" : source_text ,"contents": contents_text ,"link":link_text }  
        print(page)
        
        df = pd.DataFrame(result)  #df로 변환
        page += 10
    
    
    # 새로 만들 파일이름 지정
    outputFileName = '%s-%s-%s  %s시 %s분 %s초 merging.xlsx' % (now.year, now.month, now.day, now.hour, now.minute, now.second)
    df.to_excel(RESULT_PATH+outputFileName,sheet_name='sheet1')
    
    

def main():
    info_main = input("="*50+"\n"+"입력 형식에 맞게 입력해주세요."+"\n"+" 시작하시려면 Enter를 눌러주세요."+"\n"+"="*50)
    
    maxpage = input("최대 크롤링할 페이지 수 입력하시오: ")  
    query = input("검색어 입력: ")  
    sort = input("뉴스 검색 방식 입력(관련도순=0  최신순=1  오래된순=2): ")    #관련도순=0  최신순=1  오래된순=2
    s_date = input("시작날짜 입력(2020.07.01):")  #2020.07.01
    e_date = input("끝날짜 입력(2020.07.17):")    #2020.07.17
    
    crawler(maxpage,query,sort,s_date,e_date) 
    
main()

print("작업완료")
# Out:
# Writing d:/weekend/0718/naver_excel.py
